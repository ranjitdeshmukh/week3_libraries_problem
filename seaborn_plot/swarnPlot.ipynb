# %%
"""
@author : Ranjit
Created Date : 3/10/2021
Updated date : 3/10/2021
Title : swarn plot
"""
# Out:
# '\n@author : Ranjit\nCreated Date : 3/10/2021\nUpdated date : 3/10/2021\nTitle : swarn plot\n'

# %%
import seaborn
 
fmri = seaborn.load_dataset("tips")
 
seaborn.swarmplot(x="total_bill",
                  y="size",
                  data=fmri)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='size'>
