# %%
"""
@author Ranjit
Created date : 3/10/2021
Updated Date :10/3/2021
Title: Scatter PLot
"""

# %%
import seaborn
 
 
seaborn.set(style='whitegrid')
fmri = seaborn.load_dataset("titanic")
 
seaborn.scatterplot(x="sex",
                    y="survived",
                    data=fmri)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='survived'>
