# %%
import matplotlib.pyplot as plt

x1 = [10,20,30]
y2 = [20,40,10]

plt.plot(x1, y2, label = 'lines1')

x2 = [10,20,30]
y2 = [40,10,30]
# plotting the line 2 points 
plt.plot(x2, y2, label = "line 2")
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.legend()
