# %%
"""
@author : Ranjit
Created date : 10/3/2021
Updated date : 10/3/2021
Title : box plot
"""
# Out:
# '\n@author : Ranjit\nCreated date : 10/3/2021\nUpdated date : 10/3/2021\nTitle : box plot\n'

# %%
# import the required library  
import numpy as np  
import pandas as pd  
import matplotlib.pyplot as plt  
import seaborn as sns

    
titanic = sns.load_dataset("tips")
  
sns.boxplot(x = 'day', y = 'total_bill', data = titanic)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>
